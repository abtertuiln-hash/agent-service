# %% [markdown]
# ## 测试

# %%
from app.core.config import *

print (settings.model_dump_json(indent=2))
# Out:
# {
#   "app": {
#     "name": "安心保",
#     "host": "0.0.0.0",
#     "port": 8001,
#     "debug": true
#   },
#   "db": {
#     "host": "192.168.150.101",
#     "port": 5432,
#     "name": "insurance",
#     "user": "insurance",
#     "password": "insurance123",
#     "url": "postgresql+asyncpg://insurance:insurance123@192.168.150.101:5432"
#   },
#   "llm": {
#     "api_key": "sk-6f566fc2454f44588c2969de2a1a99d7",
#     "chat_model": "deepseek-v4-flash"
#   },
#   "logging": {
#     "level": "INFO"
#   }
# }
