# %%
import os

from dotenv import load_dotenv
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model

# 1. 加载环境变量
load_dotenv()  # 加载本地的.env文件,将文件中的内容合并到环境变量

# 获取环境变量中的base_url和api key
dashscope_api_key = os.getenv('DASHSCOPE_API_KEY')
dashscope_base_url = os.getenv('DASHSCOPE_BASE_URL')


# 2. 初始化模型(自定义初始化)
# langchain会根据模型名称自动推断模型厂商决定base_url ,从环境变量中自动读取对应的api_key
model = init_chat_model(
    model='qwen3.8-max',
    model_provider='openai',
    base_url = dashscope_base_url,
    api_key = dashscope_api_key,
    temperature=1.5,
    top_p=0.75,
    # 额外参数,在跟模型交互的过程中会将额外的参数合并到请求体中一起发送给模型
    extra_body={
        "thinking": {
            "type": "disabled"
        }
    }
)

tools = []

# 3. 创建Agent(绑定模型和工具)
agent = create_agent(model=model, tools=tools)

# 4. 调用模型
response = agent.invoke({'messages': [{'role': 'user', 'content': '你是谁?'}]})

# 5. 输出模型的返回结果
print(response)
# Out:
# {'messages': [HumanMessage(content='你是谁?', additional_kwargs={}, response_metadata={}, id='39ddd3a6-b343-4606-9fa0-71e04dc0d795'), AIMessage(content='我是通义千问（Qwen），由阿里云研发的超大规模语言模型。我可以回答问题、创作文字、编程、表达观点等，很高兴为你提供帮助！有什么我可以帮你的吗？', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 39, 'prompt_tokens': 27, 'total_tokens': 66, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': 27}}, 'model_provider': 'openai', 'model_name': 'qwen3.8-max', 'system_fingerprint': None, 'id': 'chatcmpl-cbbe7678-f1f1-9e2d-b66b-5acf5eeb6faa', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0465a-f624-73d0-9732-ef02d444e272-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 27, 'output_tokens': 39, 'total_tokens': 66, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}
